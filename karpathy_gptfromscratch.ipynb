# %% [markdown]
# The following work will implement Andrej Karpathy's instruction to replicate ChatGPT from scratch
#
# https://www.youtube.com/watch?v=kCc8FmEb1nY

# %% [markdown]
# Attention is all you need
# A new network architecture for sequence transduction based on attention mechanisms, without recurrence or convolutions.
# https://arxiv.org/pdf/1706.03762

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#train.py
